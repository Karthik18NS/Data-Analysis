# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cab_data=pd.read_csv(r'D:\work\data sets\greatlearning Data Analysis projects/My Uber Drives - 2016.csv')
weather_data=pd.read_csv(r'D:\work\data sets\greatlearning Data Analysis projects/weatherHistory.csv')

# %%
cab_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
weather_data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
cab_data.shape
# Out:
# (1156, 7)

# %%
weather_data.shape
# Out:
# (96453, 12)

# %%
cab_data.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
weather_data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
a=pd.concat([cab_data,weather_data])

# %%
a.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE* Formatted Date Summary Precip Type  \
# 0     5.1   Meal/Entertain            NaN     NaN         NaN
# 1     5.0              NaN            NaN     NaN         NaN
# 2     4.8  Errand/Supplies            NaN     NaN         NaN
# 3     4.7          Meeting            NaN     NaN         NaN
# 4    63.7   Customer Visit            NaN     NaN         NaN
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
a.isnull().sum()
# Out:
# START_DATE*                 96453
# END_DATE*                   96454
# CATEGORY*                   96454
# START*                      96454
# STOP*                       96454
# MILES*                      96453
# PURPOSE*                    96956
# Formatted Date               1156
# Summary                      1156
# Precip Type                  1673
# Temperature (C)              1156
# Apparent Temperature (C)     1156
# Humidity                     1156
# Wind Speed (km/h)            1156
# Wind Bearing (degrees)       1156
# Visibility (km)              1156
# Loud Cover                   1156
# Pressure (millibars)         1156
# Daily Summary                1156
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97609 entries, 0 to 96452
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   START_DATE*               1156 non-null   object
#  1   END_DATE*                 1155 non-null   object
#  2   CATEGORY*                 1155 non-null   object
#  3   START*                    1155 non-null   object
#  4   STOP*                     1155 non-null   object
#  5   MILES*                    1156 non-null   float64
#  6   PURPOSE*                  653 non-null    object
#  7   Formatted Date            96453 non-null  object
#  8   Summary                   96453 non-null  object
#  9   Precip Type               95936 non-null  object
#  10  Temperature (C)           96453 non-null  float64
#  11  Apparent Temperature (C)  96453 non-null  float64
#  12  Humidity                  96453 non-null  float64
# ...

# %%
a.fillna(0,inplace=True)

# %%
a.tail()
# Out:
#       START_DATE* END_DATE* CATEGORY* START* STOP*  MILES* PURPOSE*  \
# 96448           0         0         0      0     0     0.0        0
# 96449           0         0         0      0     0     0.0        0
# 96450           0         0         0      0     0     0.0        0
# 96451           0         0         0      0     0     0.0        0
# 96452           0         0         0      0     0     0.0        0
#
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# ...

# %%
a.keys()
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*', 'Formatted Date', 'Summary', 'Precip Type',
#        'Temperature (C)', 'Apparent Temperature (C)', 'Humidity',
#        'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
#        'Loud Cover', 'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
a['PURPOSE*'].value_counts()
# Out:
# 0                  96956
# Meeting              187
# Meal/Entertain       160
# Errand/Supplies      128
# Customer Visit       101
# Temporary Site        50
# Between Offices       18
# Moving                 4
# Airport/Travel         3
# Charity ($)            1
# Commute                1
# Name: PURPOSE*, dtype: int64

# %%
a.groupby('Precip Type').count()
# Out:
#              START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  \
# Precip Type
# 0                   1673       1673       1673    1673   1673    1673
# rain               85224      85224      85224   85224  85224   85224
# snow               10712      10712      10712   10712  10712   10712
#
#              PURPOSE*  Formatted Date  Summary  Temperature (C)  \
# Precip Type
# 0                1673            1673     1673             1673
# rain            85224           85224    85224            85224
# snow            10712           10712    10712            10712
#
#              Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# Precip Type
# 0                                1673      1673               1673
# rain                            85224     85224              85224
# snow                            10712     10712              10712
#
#              Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# Precip Type
# ...

# %%
a.groupby('Precip Type').count().plot.bar()
# Out:
# <AxesSubplot:xlabel='Precip Type'>

# %%
a['PURPOSE*'].value_counts().plot(kind='bar',figsize=(15,5),color='brown')
# Out:
# <AxesSubplot:>

# %%
x=a['Apparent Temperature (C)']
y=a['MILES*']
plt.bar(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-029deaf8c336> in <module>
# ----> 1 x=a['Apparent Temperature (C)']
#       2 y=a['MILES*']
#       3 plt.bar(x,y)
#       4 plt.show()
#
# NameError: name 'a' is not defined

# %%
a.keys()

# %%
x1=a[['MILES*','Temperature (C)','Apparent Temperature (C)','Humidity','Pressure (millibars)']]

# %%
y1='PURPOSE*'

# %%
from sklearn.model_selection import train_test_split
xtrain,ytrain,xtest,ytest=train_test_split(x1,y1,test_size=.25,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e4f74bb89bb0> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 xtrain,ytrain,xtest,ytest=train_test_split(x1,y1,test_size=.25,random_state=42)
#
# NameError: name 'x1' is not defined
